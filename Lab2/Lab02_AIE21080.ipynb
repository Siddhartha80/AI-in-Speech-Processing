# %% [markdown]
# ### Mettu Siddhartha BL.EN.U4AEI21080

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question -1

# %% [markdown]
# Find the first derivative of your speech signal with finite difference method. Listen to the first
# derivative signal and the original speech signal.

# %%
y, sr = librosa.load('Lab02.mp3')
librosa.display.waveshow(y)
plt.title('Speech Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio

# Load the speech signal
file_path = 'Lab02.mp3'
speech_signal, sr = librosa.load(file_path, sr=None)

# Compute the first derivative using finite difference method
first_derivative = np.diff(speech_signal)

# Plot the original and derivative signals
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
librosa.display.waveshow(speech_signal, sr=sr)
plt.title('Original Speech Signal')

plt.subplot(2, 1, 2)
time_axis = np.arange(0, len(first_derivative)) / sr
plt.plot(time_axis, first_derivative, color='red')
plt.title('First Derivative of Speech Signal')

plt.tight_layout()
plt.show()

# %%
import IPython.display as ipd
filename='Lab02.mp3'
ipd.Audio(filename)
y, sr = librosa.load(filename) 
librosa.display.waveshow(y) 
import numpy as np
f_d = np.array([y[1] - 2*y[0]])
for i in range(1,len(y)-1):
    f_d=np.append(f_d,y[i-1] + y[i+1] - 2*y[i]) 
f_d
librosa.display.waveshow(f_d)

# %%
# Play original audio
print("Original Audio")
Audio(data=y, rate=sr)
# Out:
# Original Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Play first derivative audio
print("First Derivative Audio")
Audio(data=f_d, rate=sr)
# Out:
# First Derivative Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Question - 2

# %% [markdown]
# Detect the points of zero crossing in the first derivative signal. Compare the average length
# between two consecutive zero crossings for speech and silence regions. Observe the pattern.

# %%
zero_crossing = np.where(np.diff(np.sign(f_d)))[0]
diff = np.diff(zero_crossing)
threshold = 1000
speech_regions = diff[diff > threshold]
silence_regions = diff[diff <= threshold]

avg_length_speech = np.mean(speech_regions)
avg_length_silence = np.mean(silence_regions)

print("Average length between consecutive zero crossings in speech regions:", avg_length_speech)
print("Average length between consecutive zero crossings in silence regions:", avg_length_silence)

plt.figure(figsize=(10, 5))
plt.plot(diff, label='All regions',color = 'red')
plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions',color = 'green')
plt.plot(np.arange(len(speech_regions), len(speech_regions) + len(silence_regions)), silence_regions, 'bo', label='Silence regions',color = 'green')
plt.title('Pattern of Zero Crossings')
plt.xlabel('Zero Crossing Difference')
plt.ylabel('Difference between Consecutive Zero Crossings')
plt.legend()
plt.show()

print("Pattern of Zero Crossings:")
print("All regions:", diff)
print("Speech regions:", speech_regions)
print("Silence regions:", silence_regions)
# Out:
# C:\Users\SRAVAN\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\SRAVAN\anaconda3\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\SRAVAN\AppData\Local\Temp\ipykernel_18204\608837131.py:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions',color = 'green')
# C:\Users\SRAVAN\AppData\Local\Temp\ipykernel_18204\608837131.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
# ...

# %% [markdown]
# ### Question - 3

# %% [markdown]
#  Speak 5 of your favorite words. Observe the length of the speech signals. Compare the lengths of
# your spoken words with those of your project team-mate.

# %%
siddhartha_files = ['aie.mp3', 'amrita.mp3', 'vishwa.mp3', 'vidyapeetham.mp3', 'bengaluru.mp3']
jaswanth_files = ['aie1.mp3', 'amrita.mp3', 'vishwa1.mp3','vidyapeetham1.mp3','bengaluru1.mp3']
words = ['aie', 'amrita', 'vishwa', 'vidyapeetham', 'bengaluru']
word_lengths_siddhartha = []
word_lengths_jaswanth = []

for word_file in siddhartha_files:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_siddhartha.append(length_seconds)

for word_file in jaswanth_files:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_jaswanth.append(length_seconds)

print("Lengths of the spoken words MINE:", word_lengths_siddhartha)
print("Lengths of the spoken words TeamMate:", word_lengths_jaswanth)

bar_width = 0.35
index = np.arange(len(words))
plt.figure(figsize=(12, 6))
plt.bar(index - bar_width/2, word_lengths_siddhartha, bar_width, label='My Words', color='skyblue')
plt.bar(index + bar_width/2, word_lengths_jaswanth, bar_width, label="Teammate's Words", color='orange')
plt.xlabel('Words')
plt.ylabel('Length (seconds)')
plt.title('Comparison of Spoken Words Length')
plt.xticks(index, words)
plt.legend()

plt.show()
# Out:
# Lengths of the spoken words MINE: [2.3535, 2.6735, 1.5335, 2.9335, 2.6135]
# Lengths of the spoken words TeamMate: [1.3378333333333334, 2.6735, 1.1778333333333333, 1.6378333333333333, 1.6978333333333333]

# %% [markdown]
# ### Question - 4

# %% [markdown]
# Select a sentence which can be used for making a statement or asking a question. Ex: “You are
# going to college on Sunday(./?)”. Record two signals – one with making the statement while other
# with asking question. Study the two signals and compare them.

# %%
statement, sr1 = librosa.load('Statement.mp3')
question, sr2 = librosa.load('question.mp3')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(statement, sr=sr,color='black')
plt.title('STATEMENT')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

question, sr = librosa.load('question.mp3')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(statement, sr=sr,color='black')
plt.title('QUESTION')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
